# %%
intents = load_intents(r'C:\Users\Lenovo\PycharmProjects\newchatbot\data\intents.json')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Lenovo\PycharmProjects\newchatbot\notebooks

# %%
intents = load_intents(r'C:\Users\Lenovo\PycharmProjects\newchatbot\data\intents.json')

# %%
print(json.dumps(intents, indent=4))
# Out:
# {
#     "intents": [
#         {
#             "tag": "greeting",
#             "patterns": [
#                 "Hello",
#                 "Hi",
#                 "How are you?",
#                 "Hey"
#             ],
#             "responses": [
#                 "Hello, how can I assist you today?",
#                 "Hi there, how can I help you?"
#             ]
#         },
#         {
#             "tag": "goodbye",
#             "patterns": [
#                 "Bye",
#                 "Goodbye",
#                 "See you later"
#             ],
#             "responses": [
#                 "Goodbye, have a nice day!",
#                 "See you later!"
#             ]
#         },
#         {
#             "tag": "thanks",
#             "patterns": [
#                 "Thank you",
#                 "Thanks",
#                 "Thanks a lot"
#             ],
#             "responses": [
#                 "You're welcome!",
#                 "Glad I could help!"
#             ]
#         }
#     ]
# }

# %%
import random
import re
from nltk.stem import WordNetLemmatizer
import json

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Sample intents data (you already have this loaded)
intents = {
    'intents': [
        {
            'tag': 'greeting',
            'patterns': ['Hello', 'Hi', 'How are you?', 'Hey'],
            'responses': ['Hello, how can I assist you today?', 'Hi there, how can I help you?']
        },
        {
            'tag': 'goodbye',
            'patterns': ['Bye', 'Goodbye', 'See you later'],
            'responses': ['Goodbye, have a nice day!', 'See you later!']
        },
        {
            'tag': 'thanks',
            'patterns': ['Thank you', 'Thanks', 'Thanks a lot'],
            'responses': ["You're welcome!", 'Glad I could help!']
        }
    ]
}

# Preprocessing function (simplified version)
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove non-alphabetic characters
    words = text.split()  # Tokenize text by splitting into words
    words = [lemmatizer.lemmatize(word) for word in words]  # Lemmatize each word
    return words

# Function to identify intent
def get_intent(user_input):
    processed_input = preprocess_text(user_input)
    for intent in intents['intents']:
        for pattern in intent['patterns']:
            if all(word in pattern.lower() for word in processed_input):
                return intent['tag']
    return None

# Function to get a response based on intent
def get_response(intent_tag):
    for intent in intents['intents']:
        if intent['tag'] == intent_tag:
            return random.choice(intent['responses'])
    return "Sorry, I didn't understand that."

# Example of processing user input
user_input = "Hi"
intent_tag = get_intent(user_input)

if intent_tag:
    response = get_response(intent_tag)
else:
    response = "I'm not sure how to respond to that."

print(response)
# Out:
# Hi there, how can I help you?

# %%
# Test different inputs
test_inputs = [
    "Hi",
    "Bye",
    "Can you tell me a joke?",
    "What is your return policy?"
]

for user_input in test_inputs:
    intent_tag = get_intent(user_input)
    response = get_response(intent_tag) if intent_tag else "I'm not sure how to respond to that."
    print(f"User input: {user_input}\nResponse: {response}\n")
# Out:
# User input: Hi
# Response: Hi there, how can I help you?
#
# User input: Bye
# Response: Goodbye, have a nice day!
#
# User input: Can you tell me a joke?
# Response: I'm not sure how to respond to that.
#
# User input: What is your return policy?
# Response: I'm not sure how to respond to that.

# %%
# Import necessary libraries
import json
import re
from nltk.stem import WordNetLemmatizer
import random

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load the intents data
def load_intents(filename):
    with open(filename, 'r') as file:
        return json.load(file)

# Load intents data from the path
intents = load_intents(r'C:\Users\Lenovo\PycharmProjects\newchatbot\data\intents.json')

# Preprocessing function (simplified version)
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text (split by spaces)
    words = text.split()

    # Lemmatize each word
    words = [lemmatizer.lemmatize(word) for word in words]
    
    return words

# Function to identify intent based on input
def get_intent(user_input):
    # Preprocess the user input
    processed_input = preprocess_text(user_input)

    # Match input with intents
    for intent in intents['intents']:
        for pattern in intent['patterns']:
            # Check if the preprocessed input matches the pattern
            if all(word in pattern.lower() for word in processed_input):
                return intent['tag']
    return None

# Function to get a response based on intent
def get_response(intent_tag):
    for intent in intents['intents']:
        if intent['tag'] == intent_tag:
            return random.choice(intent['responses'])
    return "Sorry, I didn't understand that."

# Exploring the structure of intents data
print("Exploring intents data:\n")
print(json.dumps(intents, indent=4))

# Testing intent matching with different inputs
user_input = "Hi there!"
intent_tag = get_intent(user_input)

if intent_tag:
    response = get_response(intent_tag)
else:
    response = "I'm not sure how to respond to that."

print(f"User input: {user_input}")
print(f"Response: {response}")

# Test with different inputs
test_inputs = [
    "Hello",
    "Goodbye",
    "Thanks",
    "How are you?"
]

for input_text in test_inputs:
    intent_tag = get_intent(input_text)
    response = get_response(intent_tag) if intent_tag else "I'm not sure how to respond to that."
    print(f"\nUser input: {input_text}")
    print(f"Response: {response}")
# Out:
# Exploring intents data:
#
# {
#     "intents": [
#         {
#             "tag": "greeting",
#             "patterns": [
#                 "Hello",
#                 "Hi",
#                 "How are you?",
#                 "Hey"
#             ],
#             "responses": [
#                 "Hello, how can I assist you today?",
#                 "Hi there, how can I help you?"
#             ]
#         },
#         {
#             "tag": "goodbye",
#             "patterns": [
#                 "Bye",
#                 "Goodbye",
#                 "See you later"
#             ],
#             "responses": [
#                 "Goodbye, have a nice day!",
#                 "See you later!"
#             ]
#         },
#         {
#             "tag": "thanks",
#             "patterns": [
#                 "Thank you",
#                 "Thanks",
#                 "Thanks a lot"
#             ],
#             "responses": [
#                 "You're welcome!",
#                 "Glad I could help!"
#             ]
#         }
#     ]
# }
# User input: Hi there!
# Response: I'm not sure how to respond to that.
#
# User input: Hello
# Response: Hi there, how can I help you?
#
# User input: Goodbye
# Response: See you later!
#
# User input: Thanks
# Response: Glad I could help!
#
# User input: How are you?
# Response: Hello, how can I assist you today?
